# %%
import pandas as pd
import numpy as np
import os
import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
os.getcwd()
df = pd.read_csv("data/SeriesReport-Not Seasonally Adjusted Sales - Monthly (Millions of Dollars).csv")
df["Period"] = df['Period'].astype(str).str[3:10]
df["Period"] = pd.to_datetime(df['Period'])

# %%
# Historical data (1992 - 2018)
df_train = df[(df["Period"] < datetime.datetime(2019,1,1))]
df_train["Period"]
# Out:
# 0     1992-01-01
# 1     1992-02-01
# 2     1992-03-01
# 3     1992-04-01
# 4     1992-05-01
#          ...
# 319   2018-08-01
# 320   2018-09-01
# 321   2018-10-01
# 322   2018-11-01
# 323   2018-12-01
# Name: Period, Length: 324, dtype: datetime64[ns]

# %%
# Test data (2019)
df_test = df[(df["Period"] >= datetime.datetime(2019,1,1)) & (df["Period"] <= datetime.datetime(2019,12,1))]
df_test
# Out:
#         Period     Value
# 324 2019-01-01  458089.0
# 325 2019-02-01  443708.0
# 326 2019-03-01  515694.0
# 327 2019-04-01  509413.0
# 328 2019-05-01  547130.0
# 329 2019-06-01  518273.0
# 330 2019-07-01  532103.0
# 331 2019-08-01  545247.0
# 332 2019-09-01  496074.0
# 333 2019-10-01  525539.0
# 334 2019-11-01  535352.0
# 335 2019-12-01  591380.0

# %%
# Seasonal Decomposition
from statsmodels.tsa.seasonal import seasonal_decompose
df_series = pd.Series(df_train["Value"].to_list(), index = df_train["Period"])

df_series.index = pd.to_datetime(df_series.index)

df_series.index.freq = 'MS'
result = seasonal_decompose(df_series, model='ad')
fig = result.plot()

# %%
# 1st order differentiation

from statsmodels.graphics.tsaplots import plot_acf
from matplotlib import figure
import matplotlib.pyplot as plt
f = plt.figure()
ax1 = f.add_subplot(121)
ax1.set_title('1st order diff')
ax1.plot(df_train["Value"].diff())

ax2 = f.add_subplot(122)
plot_acf(df_train["Value"].diff().dropna(),ax=ax2)
plt.show()

# %%
# 2nd order differentiation

f = plt.figure()
ax1 = f.add_subplot(121)
ax1.set_title('2nd order diff')
ax1.plot(df_train["Value"].diff().diff())

ax2 = f.add_subplot(122)
plot_acf(df_train["Value"].diff().diff().dropna(),ax=ax2)
plt.show()

# %%
# Adfuller test
from statsmodels.tsa.stattools import adfuller
result = adfuller(df_train["Value"])
print('p-value: ',result[1])
result = adfuller(df_train["Value"].diff().dropna())
print('p-value: ',result[1])
# Out:
# p-value:  0.9336399865193739
# p-value:  0.0009509562979706774

# %%
from statsmodels.tsa.arima.model import ARIMA
arima_model = ARIMA(df_train["Value"], order=(1,1,2), seasonal_order=(1,1,1,12))
model = arima_model.fit()
print(model.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Value   No. Observations:                  324
# Model:             ARIMA(1, 1, 2)x(1, 1, [1], 12)   Log Likelihood               -3227.054
# Date:                            Tue, 20 Dec 2022   AIC                           6466.108
# Time:                                    22:10:47   BIC                           6488.547
# Sample:                                         0   HQIC                          6475.077
#                                             - 324
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6355      0.238     -2.674      0.008      -1.101      -0.170
# ma.L1          0.4627      0.243      1.906      0.057      -0.013       0.938
# ma.L2         -0.1832      0.036     -5.049      0.000      -0.254      -0.112
# ar.S.L12       0.5836      0.093      6.270      0.000       0.401       0.766
# ma.S.L12      -0.7322      0.102     -7.214      0.000      -0.931      -0.533
# sigma2      5.507e+07   4.86e-09   1.13e+16      0.000    5.51e+07    5.51e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                  27.85   Jarque-Bera (JB):                12.51
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.42   Skew:                            -0.23
# Prob(H) (two-sided):                  0.07   Kurtosis:                         3.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.71e+31. Standard errors may be unstable.

# %%
y_pred = pd.Series(model.forecast(12).to_list(), index = df_test["Period"])
y_true = pd.Series(df_test["Value"].to_list(), index = df_test["Period"])

# %%
mae = np.mean(np.abs(y_pred - y_true))
rmse = np.mean((y_pred - y_true)**2)**.5

# %%
print(mae)
print(rmse)
# Out:
# 12432.826395047747
# 14504.625872314004

# %%
from matplotlib import figure
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax = y_true.plot(ax=ax,label='true')
ay = y_pred.plot(ax=ax,label='pred')
ax.legend(loc="upper right")
#fig = plot_predict(model,dynamic=False, ax=ax,
#                        plot_insample=False)
plt.show()

# %%
def run_arima_parameters(order):
    arima_model = ARIMA(df_train["Value"], order=order, seasonal_order=(1,1,1,12))
    model = arima_model.fit()
    y_pred = pd.Series(model.forecast(12).to_list(), index = df_test["Period"])
    y_true = pd.Series(df_test["Value"].to_list(), index = df_test["Period"])
    rmse = np.mean((y_pred - y_true)**2)**.5
    return rmse,model

# %%
def evaluate_models(p_values,d_values,q_values):
    best_rmse, best_order = float("inf"), None
    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p,d,q)
                rmse,model = run_arima_parameters(order)
                print('RMSE: '+str(rmse),'Order: '+str(order))
                if rmse < best_rmse:
                    best_rmse, best_order = rmse,order
    print(best_rmse, best_order)
    return best_rmse, best_order

# %%
# Running for different parameters
p_values = list(range(0,10))
d_values = list(range(0,3))
q_values = list(range(0,3))
evaluate_models(p_values,d_values,q_values)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 9372.981520856629 Order: (0, 0, 0)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 9717.82416526411 Order: (0, 0, 1)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 1191789375.8098624 Order: (0, 0, 2)
# RMSE: 19457.76328114889 Order: (0, 1, 0)
# RMSE: 15541.103022979752 Order: (0, 1, 1)
# RMSE: 14638.4216737269 Order: (0, 1, 2)
# RMSE: 185160.50035585216 Order: (0, 2, 0)
# RMSE: 21989.486992158465 Order: (0, 2, 1)
# RMSE: 15207.48332036315 Order: (0, 2, 2)
# RMSE: 9875.77675975907 Order: (1, 0, 0)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 12593.949588216305 Order: (1, 0, 1)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 11343.53981677066 Order: (1, 0, 2)
# RMSE: 16606.895868757783 Order: (1, 1, 0)
# RMSE: 14913.55321915051 Order: (1, 1, 1)
# RMSE: 14504.625872314004 Order: (1, 1, 2)
# RMSE: 146800.6848004881 Order: (1, 2, 0)
# RMSE: 16052.474404626948 Order: (1, 2, 1)
# RMSE: 22252.943573760163 Order: (1, 2, 2)
# RMSE: 20008.11627603993 Order: (2, 0, 0)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 10053.09263262262 Order: (2, 0, 1)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 10570.707641365814 Order: (2, 0, 2)
# RMSE: 14539.495975813914 Order: (2, 1, 0)
# RMSE: 14486.662463439028 Order: (2, 1, 1)
# RMSE: 16843.925913688898 Order: (2, 1, 2)
# RMSE: 75102.43103077284 Order: (2, 2, 0)
# RMSE: 15146.151712151786 Order: (2, 2, 1)
# RMSE: 15003.161414470484 Order: (2, 2, 2)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 11275.557932829483 Order: (3, 0, 0)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 19970.58472442386 Order: (3, 0, 1)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 18936.717328982446 Order: (3, 0, 2)
# RMSE: 14939.09353811397 Order: (3, 1, 0)
# RMSE: 14644.631802871108 Order: (3, 1, 1)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 15427.393230927255 Order: (3, 1, 2)
# RMSE: 64020.858500378396 Order: (3, 2, 0)
# RMSE: 15260.845170391438 Order: (3, 2, 1)
# RMSE: 16700.45888940665 Order: (3, 2, 2)
# RMSE: 19751.711726117803 Order: (4, 0, 0)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 14113.772455368291 Order: (4, 0, 1)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 11104.592852823565 Order: (4, 0, 2)
# RMSE: 13915.901827203825 Order: (4, 1, 0)
# RMSE: 13933.877281010193 Order: (4, 1, 1)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 15382.848284765403 Order: (4, 1, 2)
# RMSE: 55731.629417023236 Order: (4, 2, 0)
# RMSE: 15207.58848527082 Order: (4, 2, 1)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 15818.699691612963 Order: (4, 2, 2)
# RMSE: 19382.64985768801 Order: (5, 0, 0)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 11416.935687685056 Order: (5, 0, 1)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 10246.172870512712 Order: (5, 0, 2)
# RMSE: 13974.622281719041 Order: (5, 1, 0)
# RMSE: 14367.853020657452 Order: (5, 1, 1)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 15013.866240421514 Order: (5, 1, 2)
# RMSE: 47406.0951660795 Order: (5, 2, 0)
# RMSE: 16259.68704867634 Order: (5, 2, 1)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 16075.017766089963 Order: (5, 2, 2)
# RMSE: 19141.50820353962 Order: (6, 0, 0)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 11686.805711274234 Order: (6, 0, 1)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 11063.233665741085 Order: (6, 0, 2)
# RMSE: 14779.337976811616 Order: (6, 1, 0)
# RMSE: 14594.37915818671 Order: (6, 1, 1)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 14456.86742814767 Order: (6, 1, 2)
# RMSE: 44955.490042751764 Order: (6, 2, 0)
# RMSE: 18554.379100346014 Order: (6, 2, 1)
# RMSE: 17811.731686347703 Order: (6, 2, 2)
# RMSE: 19289.324489865714 Order: (7, 0, 0)
# RMSE: 19138.54330962616 Order: (7, 0, 1)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 12258.731293845269 Order: (7, 0, 2)
# RMSE: 13930.398277988874 Order: (7, 1, 0)
# RMSE: 13911.235467038065 Order: (7, 1, 1)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 14957.407196264121 Order: (7, 1, 2)
# RMSE: 39178.81369522398 Order: (7, 2, 0)
# RMSE: 18517.042113600706 Order: (7, 2, 1)
# RMSE: 17760.32460591765 Order: (7, 2, 2)
# RMSE: 18736.677387295513 Order: (8, 0, 0)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 12146.894381935514 Order: (8, 0, 1)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 11929.312829437018 Order: (8, 0, 2)
# RMSE: 13875.271512273986 Order: (8, 1, 0)
# RMSE: 14179.62773953009 Order: (8, 1, 1)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 14106.957687947137 Order: (8, 1, 2)
# RMSE: 34383.160073722494 Order: (8, 2, 0)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 19181.19971632514 Order: (8, 2, 1)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 19220.165884352424 Order: (8, 2, 2)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 17564.069541086075 Order: (9, 0, 0)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 11985.178057998022 Order: (9, 0, 1)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 11675.749567275143 Order: (9, 0, 2)
# RMSE: 14738.332990568018 Order: (9, 1, 0)
# RMSE: 15102.228780876172 Order: (9, 1, 1)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 14649.768314475947 Order: (9, 1, 2)
# RMSE: 36033.76071368078 Order: (9, 2, 0)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 19920.515600316015 Order: (9, 2, 1)
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# RMSE: 20299.314981182433 Order: (9, 2, 2)
# 9372.981520856629 (0, 0, 0)
# (9372.981520856629, (0, 0, 0))

# %%
#Best model for RMSE with order (0,0,0)
from statsmodels.tsa.arima.model import ARIMA
arima_model = ARIMA(df_train["Value"], order=(0,0,0), seasonal_order=(1,1,1,12))
model = arima_model.fit()
y_pred = pd.Series(model.forecast(12).to_list(), index = df_test["Period"])
y_true = pd.Series(df_test["Value"].to_list(), index = df_test["Period"])
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/salesdata/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
#Plotting real value vs predicted for 2019 (smaller RMSE than before)
from matplotlib import figure
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax = y_true.plot(ax=ax,label='true')
ay = y_pred.plot(ax=ax,label='pred')
ax.legend(loc="upper right")
plt.show()
